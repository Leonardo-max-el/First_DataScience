# %% [markdown]
# Gestion de la informacion duplicado o faltante, si el dato no nos interesa lo habitual es eliminarlos

# %%
#Modificación de la estrucutura de nuestra base de datos
import pandas as pd
df = pd.read_csv('C:/Users/Jhoana FE/Desktop/datasets/base_datos_2008.csv', nrows=1e6)
print(df.columns)
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()  # Elimina espacios en blanco
print(df.columns.tolist())  # Verifica nuevamente
# Out:
# ['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime', 'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum', 'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay', 'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut', 'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay']

# %%
#Duplicamos los datos con el mismo dataframe
dfduplicate = pd.concat([df, df])

# %%
#Reordenamos el dataframe
dfduplicate = dfduplicate.sample(frac=1)

# %%
#Eliminamos los casos duplicados
dfclean = dfduplicate.drop_duplicates()

# %%
#Comprobamos si nuestro nuevo df es igual al df original 
len(dfclean) == len(df)
# Out:
# False

# %%
len(dfclean)
# Out:
# 999996

# %% [markdown]
# Gestion de datos mas especifico usando la funcion de datos groop duplicate

# %%
dfclean.drop_duplicates(subset = "DayofMonth")
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 218384  2008      1          25          5    757.0         800   1612.0
# 172338  2008      1           2          3    720.0         715    906.0
# 388147  2008      1          27          7      NaN        1115      NaN
# 449296  2008      1          28          1   1233.0        1243   1409.0
# 202325  2008      1          21          1   2153.0        2005   2338.0
# 270911  2008      1          12          6   1901.0        1900   2035.0
# 809687  2008      2          29          5   1011.0        1017   1200.0
# 555908  2008      1          18          5   2135.0        2120      4.0
# 749949  2008      2           4          1   1555.0        1445   1734.0
# 360283  2008      1           9          3   1236.0        1241   1812.0
# 789230  2008      2          16          6    625.0         615    722.0
# 999759  2008      2          23          6   1708.0        1710   1830.0
# ...

# %%
#Gestionamos los datos faltantes
#Obtenemos datos vacios aqui ninguna columna no tiene ninguna dato faltantes
df.dropna()
# Out:
# Empty DataFrame
# Columns: [Year, Month, DayofMonth, DayOfWeek, DepTime, CRSDepTime, ArrTime, CRSArrTime, UniqueCarrier, FlightNum, TailNum, ActualElapsedTime, CRSElapsedTime, AirTime, ArrDelay, DepDelay, Origin, Dest, Distance, TaxiIn, TaxiOut, Cancelled, CancellationCode, Diverted, CarrierDelay, WeatherDelay, NASDelay, SecurityDelay, LateAircraftDelay]
# Index: []
#
# [0 rows x 29 columns]

# %%
df.dropna(thresh=25)
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 4       2008      1           3          4   1829.0        1755   1959.0
# 6       2008      1           3          4   1937.0        1830   2037.0
# 11      2008      1           3          4   1644.0        1510   1845.0
# 16      2008      1           3          4   1452.0        1425   1640.0
# 18      2008      1           3          4   1323.0        1255   1526.0
# ...      ...    ...         ...        ...      ...         ...      ...
# 999973  2008      2          23          6   1306.0        1235   1514.0
# 999983  2008      2          28          4   1458.0        1235   1645.0
# 999988  2008      2           4          1   1754.0        1655   2056.0
# 999989  2008      2           5          2   1812.0        1655   2129.0
# 999994  2008      2          11          1   1717.0        1655   2030.0
#
#         CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
df.dropna(thresh=len(df.columns)-2)
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 4       2008      1           3          4   1829.0        1755   1959.0
# 6       2008      1           3          4   1937.0        1830   2037.0
# 11      2008      1           3          4   1644.0        1510   1845.0
# 16      2008      1           3          4   1452.0        1425   1640.0
# 18      2008      1           3          4   1323.0        1255   1526.0
# ...      ...    ...         ...        ...      ...         ...      ...
# 999973  2008      2          23          6   1306.0        1235   1514.0
# 999983  2008      2          28          4   1458.0        1235   1645.0
# 999988  2008      2           4          1   1754.0        1655   2056.0
# 999989  2008      2           5          2   1812.0        1655   2129.0
# 999994  2008      2          11          1   1717.0        1655   2030.0
#
#         CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
#Filtar un comluna de dato faltante
df.dropna(subset=["CancellationCode"])
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 178     2008      1           3          4      NaN         700      NaN
# 373     2008      1           3          4      NaN        1100      NaN
# 399     2008      1           3          4      NaN         905      NaN
# 401     2008      1           3          4      NaN        1620      NaN
# 415     2008      1           3          4      NaN        1930      NaN
# ...      ...    ...         ...        ...      ...         ...      ...
# 999913  2008      2          11          1      NaN         855      NaN
# 999919  2008      2          17          7      NaN         855      NaN
# 999961  2008      2          17          7      NaN        1445      NaN
# 999971  2008      2          22          5      NaN        1235      NaN
# 999999  2008      2          17          7      NaN        1655      NaN
#
#         CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...
