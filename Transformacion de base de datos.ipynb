# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Modificación de la estrucutura de nuestra base de datos
import pandas as pd
df = pd.read_csv('C:/Users/Jhoana FE/Desktop/datasets/base_datos_2008.csv', sep=';')
print(df.columns)
# Out:
# Index(['Year,Month,DayofMonth,DayOfWeek,DepTime,CRSDepTime,ArrTime,CRSArrTime,UniqueCarrier,FlightNum,TailNum,ActualElapsedTime,CRSElapsedTime,AirTime,ArrDelay,DepDelay,Origin,Dest,Distance,TaxiIn,TaxiOut,Cancelled,CancellationCode,Diverted,CarrierDelay,WeatherDelay,NASDelay,SecurityDelay,LateAircraftDelay'], dtype='object')

# %%
df.columns = df.columns.str.strip()  # Elimina espacios en blanco
print(df.columns.tolist())  # Verifica nuevamente
# Out:
# ['Year,Month,DayofMonth,DayOfWeek,DepTime,CRSDepTime,ArrTime,CRSArrTime,UniqueCarrier,FlightNum,TailNum,ActualElapsedTime,CRSElapsedTime,AirTime,ArrDelay,DepDelay,Origin,Dest,Distance,TaxiIn,TaxiOut,Cancelled,CancellationCode,Diverted,CarrierDelay,WeatherDelay,NASDelay,SecurityDelay,LateAircraftDelay']

# %%
df['ArrDelay']  # Reemplaza con el nombre exacto si es diferente

# %%
# Acceder a la columna 'ArrDelay' (asegúrate de que exista)
if 'ArrDelay' in df.columns:
    df['HoursDelay'] = round(df['ArrDelay'] / 60, 2)
    print(df.head())
else:
    print("La columna 'ArrDelay' no existe en el DataFrame.")

# %%
#columna nueva
df['HoursDelay'] = round(df['ArrDelay'] / 60, 2)  # Crea la nueva columna
print(df.head())  # Muestra las primeras filas del DataFrame para verificar la nueva columna
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiOut  Cancelled  \
# 0        2225            WN        335  ...     8.0          0
# 1        1000            WN       3231  ...    10.0          0
# 2         750            WN        448  ...    17.0          0
# 3        1100            WN       1746  ...     7.0          0
# 4        1925            WN       3920  ...    10.0          0
#
#    CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# 0               NaN         0           NaN           NaN      NaN
# ...

# %%
#Eliminar una columna en concreto
del(df['HoursDelay'])  # Elimina la columna 'HoursDelay'

# %%
df.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
# 2         750            WN        448  ...    3.0     17.0          0
# 3        1100            WN       1746  ...    3.0      7.0          0
# 4        1925            WN       3920  ...    3.0     10.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
#Borrar varias columnas a la vez
df.drop(['Diverted','Cancelled','Year'], axis=1, inplace=True)  # Elimina las columnas 'Diverted', 'Cancelled' y 'Year'
df.head()  # Muestra las primeras filas del DataFrame para verificar la eliminación de columnas
# Out:
#    Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 0      1           3          4   2003.0        1955   2211.0        2225
# 1      1           3          4    754.0         735   1002.0        1000
# 2      1           3          4    628.0         620    804.0         750
# 3      1           3          4    926.0         930   1054.0        1100
# 4      1           3          4   1829.0        1755   1959.0        1925
#
#   UniqueCarrier  FlightNum TailNum  ...  Dest  Distance  TaxiIn  TaxiOut  \
# 0            WN        335  N712SW  ...   TPA       810     4.0      8.0
# 1            WN       3231  N772SW  ...   TPA       810     5.0     10.0
# 2            WN        448  N428WN  ...   BWI       515     3.0     17.0
# 3            WN       1746  N612SW  ...   BWI       515     3.0      7.0
# 4            WN       3920  N464WN  ...   BWI       515     3.0     10.0
#
#    CancellationCode CarrierDelay WeatherDelay  NASDelay  SecurityDelay  \
# ...

# %%
df.head()
# Out:
#    Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 0      1           3          4   2003.0        1955   2211.0        2225
# 1      1           3          4    754.0         735   1002.0        1000
# 2      1           3          4    628.0         620    804.0         750
# 3      1           3          4    926.0         930   1054.0        1100
# 4      1           3          4   1829.0        1755   1959.0        1925
#
#   UniqueCarrier  FlightNum TailNum  ...  Dest  Distance  TaxiIn  TaxiOut  \
# 0            WN        335  N712SW  ...   TPA       810     4.0      8.0
# 1            WN       3231  N772SW  ...   TPA       810     5.0     10.0
# 2            WN        448  N428WN  ...   BWI       515     3.0     17.0
# 3            WN       1746  N612SW  ...   BWI       515     3.0      7.0
# 4            WN       3920  N464WN  ...   BWI       515     3.0     10.0
#
#    CancellationCode CarrierDelay WeatherDelay  NASDelay  SecurityDelay  \
# ...

# %%
#Eliminar filas
df.drop(0)
# Out:
#          Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 1            1           3          4    754.0         735   1002.0
# 2            1           3          4    628.0         620    804.0
# 3            1           3          4    926.0         930   1054.0
# 4            1           3          4   1829.0        1755   1959.0
# 5            1           3          4   1940.0        1915   2121.0
# ...        ...         ...        ...      ...         ...      ...
# 7009723     12          13          6   1002.0         959   1204.0
# 7009724     12          13          6    834.0         835   1021.0
# 7009725     12          13          6    655.0         700    856.0
# 7009726     12          13          6   1251.0        1240   1446.0
# 7009727     12          13          6   1110.0        1103   1413.0
#
#          CRSArrTime UniqueCarrier  FlightNum TailNum  ...  Dest  Distance  \
# 1              1000            WN       3231  N772SW  ...   TPA       810
# ...

# %%
#Si quisierasmos eliminar varias filas a la vez
df.drop(range(0, 10), inplace=True)  # Elimina las filas de la 0 a la 9 (10 filas en total)
df.head()  # Muestra las primeras filas del DataFrame para verificar la eliminación de filas
# Out:
#     Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 10      1           3          4    706.0         700    916.0         915
# 11      1           3          4   1644.0        1510   1845.0        1725
# 12      1           3          4   1426.0        1430   1426.0        1425
# 13      1           3          4    715.0         715    720.0         710
# 14      1           3          4   1702.0        1700   1651.0        1655
#
#    UniqueCarrier  FlightNum TailNum  ...  Dest  Distance  TaxiIn  TaxiOut  \
# 10            WN        100  N690SW  ...   MCO       828     5.0     19.0
# 11            WN       1333  N334SW  ...   MCO       828     6.0      8.0
# 12            WN        829  N476WN  ...   MDW       162     9.0     12.0
# 13            WN       1016  N765SW  ...   MDW       162     7.0     21.0
# 14            WN       1827  N420WN  ...   MDW       162     4.0     10.0
#
# ...

# %%
#Como añadir nuevas filas 
dfATL = df[df.Origin == 'ATL']  # Filtra el DataFrame para obtener solo las filas donde 'Origin' es 'ATL'
dfHOU = df[df.Origin == 'HOU']

# %%
newdf = pd.concat([dfATL, dfHOU], ignore_index=True)

# %%
newdf = pd.concat([dfHOU])  # Añade las filas filtradas de 'HOU' al DataFrame original
print(newdf.head())  # Muestra las primeras filas del nuevo DataFrame para verificar la adición de filas
# Out:
#       Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 3269      1           4          5   1910.0        1910   2025.0        2025
# 3270      1           4          5   1345.0        1345   1453.0        1500
# 3271      1           4          5    736.0         735    839.0         850
# 3272      1           4          5   1603.0        1550   1647.0        1635
# 3273      1           4          5   2105.0        2105   2151.0        2150
#
#      UniqueCarrier  FlightNum TailNum  ...  Dest  Distance  TaxiIn  TaxiOut  \
# 3269            WN        823  N252WN  ...   ABQ       759     6.0     11.0
# 3270            WN        901  N374SW  ...   ABQ       759     3.0     14.0
# 3271            WN        957  N504SW  ...   ABQ       759     3.0      9.0
# 3272            WN        231  N402WN  ...   AUS       148     5.0     10.0
# 3273            WN        570  N510SW  ...   AUS       148     7.0     11.0
#
# ...

# %%
newdf.Origin
# Out:
# 3269       HOU
# 3270       HOU
# 3271       HOU
# 3272       HOU
# 3273       HOU
#           ...
# 7003419    HOU
# 7004690    HOU
# 7005947    HOU
# 7007233    HOU
# 7008545    HOU
# Name: Origin, Length: 55933, dtype: object
